# %% [markdown]
# # 문자열 추출하기

# %%
word = 'grail'
sent = 'a scratch'

# %%
print(word[0])
print(sent[0])
print(word[0:3])
# Out:
# g
# a
# gra

# %%
print(sent[-1])
print(sent[-9:-8])
print(sent[0:-8])
# Out:
# h
# a
# a

# %% [markdown]
# # 전체 문자열 추출하기

# %%
print(sent[2:-1])
print(sent[-7:-1])
# Out:
# scratc
# scratc

# %%
s_len=len(sent)
print(s_len)
print(sent[2:s_len])
# Out:
# 9
# scratch

# %% [markdown]
# # 왼쪽이나 오른쪽 범위를 지정하지 않고 문자열 추출하기

# %%
print(word[0:3])
print(word[:3])
# Out:
# gra
# gra

# %%
print(sent[2:len(sent)])
print(sent[2:])
# Out:
# scratch
# scratch

# %%
print(sent[:])
# Out:
# a scratch

# %%
print(sent[::2])
# Out:
# asrth

# %% [markdown]
# # join, splitlines, replace 메서드 실습하기

# %%
# join 메소드
d1 = '40°'
m1 = "46'"
s1 = '52.837"'
u1 = 'N'

d2 = '73°'
m2 = "58'"
s2 = '26.302"'
u2 = 'W'

coords = ' '.join([d1, m1, s1, u1, d2, m2, s2, u2])
print(coords)
# Out:
# 40° 46' 52.837" N 73° 58' 26.302" W

# %%
# splitlines 메소드
multi_str = """Guard: What? Ridden on a horse?
King Arthur: Yes!
Guard: You're using coconuts!
King Arthur: What?
Guard: You've got ... coconut[s] and you're bangin' 'em together.
"""
print(multi_str)

multi_str_split = multi_str.splitlines()
print(multi_str_split)
# Out:
# Guard: What? Ridden on a horse?
# King Arthur: Yes!
# Guard: You're using coconuts!
# King Arthur: What?
# Guard: You've got ... coconut[s] and you're bangin' 'em together.
#
# ['Guard: What? Ridden on a horse?', 'King Arthur: Yes!', "Guard: You're using coconuts!", 'King Arthur: What?', "Guard: You've got ... coconut[s] and you're bangin' 'em together. "]

# %%
guard = multi_str_split[::2]
print(guard)
# Out:
# ['Guard: What? Ridden on a horse?', "Guard: You're using coconuts!", "Guard: You've got ... coconut[s] and you're bangin' 'em together. "]

# %%
# replace 메소드
guard = multi_str.replace("Guard: ", "").splitlines()[::2]
print(guard)
# Out:
# ['What? Ridden on a horse?', "You're using coconuts!", "You've got ... coconut[s] and you're bangin' 'em together. "]

# %% [markdown]
# # 문자열 포매팅 실습하기

# %%
# {} : 플레이스 홀더
var = 'flesh wound'
s = "It's just a {}!"

print(s.format(var))
print(s.format('scratch'))
# Out:
# It's just a flesh wound!
# It's just a scratch!

# %%
s = """Black Knight: 'Tis but a {0}.
King Arthur: A {0}? Your arm's off!
"""
print(s.format('scratch'))
# Out:
# Black Knight: 'Tis but a scratch.
# King Arthur: A scratch? Your arm's off!

# %%
s = 'Hayden Planetarium Coordinates: {lat}, {lon}'
print(s.format(lat='40.7815° N', lon='73.9733° W'))
# Out:
# Hayden Planetarium Coordinates: 40.7815° N, 73.9733° W

# %% [markdown]
# # 숫자 데이터 포매팅하기

# %%
print('Some digits of pi: {}'.format(3.14159265359))
# Out:
# Some digits of pi: 3.14159265359

# %%
print("In 2005, Lu Chao of China recited {:,} digits of pi".format(67890))
# Out:
# In 2005, Lu Chao of China recited 67,890 digits of pi

# %%
print("I remember {0:.4} or {0:.4%} of what Lu Chao recited".format(7/67890))
# Out:
# I remember 0.0001031 or 0.0103% of what Lu Chao recited

# %%
print("My ID number is {0:05d}".format(42))
# Out:
# My ID number is 00042

# %% [markdown]
# # % 연산자로 포매팅하기

# %%
s = 'I only know %d digits of pi' % 7
print(s)
# Out:
# I only know 7 digits of pi

# %%
print('Some digits of %(cont)s: %(value).2f' % {'cont': 'e', 'value': 2.718})
# Out:
# Some digits of e: 2.72

# %% [markdown]
# # f-strings로 포매팅 사용하기

# %%
var = 'flesh wound'
s = f"It's just a {var}!"
print(s)
# Out:
# It's just a flesh wound!

# %%
lat='40.7815°N'
lon='73.9733°W'
s = f'Hayden Planetarium Coordinates: {lat}, {lon}'
print(s)
# Out:
# Hayden Planetarium Coordinates: 40.7815°N, 73.9733°W

# %% [markdown]
# # 정규식으로 전화번호 패턴 찾기

# %%
import re

tele_num = '1234567890'

# %%
m = re.match(pattern='\d\d\d\d\d\d\d\d\d\d', string=tele_num)
print(type(m))
print(m)
# Out:
# <class 're.Match'>
# <re.Match object; span=(0, 10), match='1234567890'>
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_1083/3128620934.py:1: SyntaxWarning: invalid escape sequence '\d'
#   m = re.match(pattern='\d\d\d\d\d\d\d\d\d\d', string=tele_num)

# %%
print(bool(m))

if m:
    print('match')
else:
    print('no match')
# Out:
# True
# match

# %%
# 첫 번째 인덱스 반환
print(m.start())
# 마지막 인덱스 반환
print(m.end())
# 찾은 패턴의 첫 번재와 마지막 인덱스 한번에 반환
print(m.span())
# 찾아낸 패턴 반환
print(m.group())
# Out:
# 0
# 10
# (0, 10)
# 1234567890

# %%
tele_num_spaces = '123 456 7890'
m = re.match(pattern='\d{10}', string=tele_num_spaces)
print(m)
# Out:
# None
# no match
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_1083/2524883540.py:2: SyntaxWarning: invalid escape sequence '\d'
#   m = re.match(pattern='\d{10}', string=tele_num_spaces)

# %%
if m:
    print('match')
else:
    print('no match')
# Out:
# no match

# %%
p = '\d{3}\s?\d{3}\s?\d{4}'
m = re.match(pattern=p, string=tele_num_spaces)
print(m)
# Out:
# <re.Match object; span=(0, 12), match='123 456 7890'>
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_1083/2925584631.py:1: SyntaxWarning: invalid escape sequence '\d'
#   p = '\d{3}\s?\d{3}\s?\d{4}'

# %%
tele_num_space_paren_dash = '(123) 456-7890'
p = '\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'
m = re.match(pattern=p, string=tele_num_space_paren_dash)
print(m)
# Out:
# <re.Match object; span=(0, 14), match='(123) 456-7890'>
# <>:2: SyntaxWarning: invalid escape sequence '\('
# <>:2: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipykernel_1083/3904624318.py:2: SyntaxWarning: invalid escape sequence '\('
#   p = '\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'

# %%
cnty_tele_num_space_paren_dash = '+1 (123) 456-7890'
p = '\+?1\s?\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'
m = re.match(pattern=p, string=cnty_tele_num_space_paren_dash)
print(m)
# Out:
# <re.Match object; span=(0, 17), match='+1 (123) 456-7890'>
# <>:2: SyntaxWarning: invalid escape sequence '\+'
# <>:2: SyntaxWarning: invalid escape sequence '\+'
# /tmp/ipykernel_1083/2791270752.py:2: SyntaxWarning: invalid escape sequence '\+'
#   p = '\+?1\s?\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'

# %% [markdown]
# # compile 메서드로 정규식 메서드 사용하기

# %%
p = re.compile('\d{10}')
s = '1234567890'
m = p.match(s)
print(m)
# Out:
# <re.Match object; span=(0, 10), match='1234567890'>
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_1083/623068502.py:1: SyntaxWarning: invalid escape sequence '\d'
#   p = re.compile('\d{10}')
