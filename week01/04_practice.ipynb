# %% [markdown]
# # 앤스콤 데이터 집합 불러오기

# %%
import seaborn as sns
anscombe=sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89
# <class 'pandas.core.frame.DataFrame'>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

dataset_1=anscombe[anscombe['dataset']=='I']
plt.plot(dataset_1['x'],dataset_1['y'])
# Out:
# <div id='20eb1b72-232c-48e3-9e28-2783e5d6535f'></div>

# %%
plt.plot(dataset_1['x'],dataset_1['y'],'o')
# Out:
# <div id='771b3aca-9d9c-490b-90bc-e6bc389ff3c8'></div>

# %% [markdown]
# # matplotlib 라이브러리로 간단한 그래프 그리기

# %% [markdown]
# # 한 번에 4개의 그래프 그리기

# %%
dataset_2=anscombe[anscombe['dataset']=='II']
dataset_3=anscombe[anscombe['dataset']=='III']
dataset_4=anscombe[anscombe['dataset']=='IV']

fig=plt.figure()
axes1=fig.add_subplot(2,2,1)
axes2=fig.add_subplot(2,2,2)
axes3=fig.add_subplot(2,2,3)
axes4=fig.add_subplot(2,2,4)
# Out:
# <div id='2d343cbb-23cc-4416-896d-7445c1bb2e51'></div>

# %%
axes1.plot(dataset_1['x'],dataset_1['y'],'o')
axes2.plot(dataset_2['x'],dataset_2['y'],'o')
axes3.plot(dataset_3['x'],dataset_3['y'],'o')
axes4.plot(dataset_4['x'],dataset_4['y'],'o')

# %%
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")
# Out:
# Text(0.5, 1.0, 'dataset_4')

# %%
fig.suptitle("Anscombe Data")

# %%
fig.tight_layout()

# %% [markdown]
# # 기초 그래프 그리기 - 히스토그램, 산점도, 박스 그래프

# %% [markdown]
# # 단변량 그래프 그리기 - 히스토그램

# %%
tips=sns.load_dataset("tips")
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
fig=plt.figure()
axes1=fig.add_subplot(1,1,1,)
# Out:
# <div id='227a3f93-f332-431e-90ff-a05b464a3fcf'></div>

# %%
axes1.hist(tips['total_bill'],bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig

# %%
scatter_plot=plt.figure()
axes1=scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <div id='c296f8eb-7169-40d7-b1f6-7de62be834f5'></div>
# Text(0, 0.5, 'Tip')

# %%
boxplot=plt.figure()
axes1=boxplot.add_subplot(1,1,1)

axes1.boxplot([
    tips[tips['sex']=='Female']['tip'],
    tips[tips['sex']=='Male']['tip']],
    labels=['Female','Male'])
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# <div id='4be1341a-edaa-4e39-93d1-7a0c87e82bd5'></div>
# C:\Users\dnamu\AppData\Local\Temp\ipykernel_37916\3831671.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes1.boxplot([
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# # 다변량 그래프 그리기

# %%
def recode_sex(sex):
    if sex=='Female':
        return 0
    else:
        return 1

# %%
tips['sex_color']=tips['sex'].apply(recode_sex)

# %%
scatter_plot=plt.figure()
axes1=scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size']*10,
    c=tips['sex_color'],alpha=0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <div id='4d87d14f-8eda-4c58-9507-8a9e02be8c00'></div>
# Text(0, 0.5, 'Tip')

# %%
import seaborn as sns
tips=sns.load_dataset("tips")

# %%
ax=plt.subplots()
ax=sns.distplot(
    tips['total_bill'])
ax.set_title('Total Bill Histogram with Density plot')
# Out:
# <div id='8a6f2ee0-9fe8-4689-8d9f-3d82a67bbd28'></div>
# C:\Users\dnamu\AppData\Local\Temp\ipykernel_37916\3094187459.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(
# Text(0.5, 1.0, 'Total Bill Histogram with Density plot')

# %%
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <div id='e86658fc-ed82-4e72-b8f0-2822723c9bf6'></div>
# C:\Users\dnamu\AppData\Local\Temp\ipykernel_37916\295866130.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(tips['total_bill'],kde=False)
# Text(0, 0.5, 'Frequency')

# %%
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],hist=False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')

# %%
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot)
ax.set_xlabel('Total Bill')

# %%
ax=plt.subplots()
ax=sns.countplot('day',data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

# %%
ax=plt.subplots()
ax=sns.regplot(x='total_bill',y='tip',data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <div id='0737b1f3-359c-42e3-a96f-88618997b982'></div>
# Text(0, 0.5, 'Tip')

# %%
ax=plt.subplots()
ax=sns.regplot(x='total_bill',y='tip',data=tips,fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

# %%
joint=sns.jointplot(x='total_bill',y='tip',data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint plot of Total Bill and Tip',fontsize=10,y=1.03)
# Out:
# <div id='d06bb741-c882-4969-aaa1-c91af802e075'></div>
# Text(0.5, 1.03, 'Joint plot of Total Bill and Tip')

# %%
joint=sns.jointplot(x='total_bill',y='tip',data=tips,kind="hex")
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Hexbin Joint plot of Total Bill and Tip',fontsize=10,y=1.03)
# Out:
# <div id='0149c013-704a-42c6-83af-2a4ff78d08a2'></div>
# Text(0.5, 1.03, 'Hexbin Joint plot of Total Bill and Tip')

# %%
ax=plt.subplots()
ax=sns.kdeplot(data=tips['total_bill'],data2=tips['tip'],shade=True)
ax.set_title('Kernel Density Plot of total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

# %%
ax=plt.subplots()
ax=sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# <div id='1ad40106-14f6-426c-a1ce-a465afac692e'></div>
# Text(0, 0.5, 'Aberage total bill')

# %%
ax=plt.subplots()
ax=sns.boxplot(x='time',y='total_bill',data=tips)
ax.set_title('Boxplot of average total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total bill')

# %%
ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',data=tips)
ax.set_title('Violin plot of average total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total bill')

# %%
fig=sns.pairplot(tips)
# Out:
# <div id='bb31d6ed-46fc-4880-b8bb-1bed5456e1f7'></div>

# %%
pair_grid=sns.PairGrid(tips)
pair_grid=pair_grid.map_upper(sns.regplot)
pair_grid=paer(sns.kdeplot)
pair_grid=pair_grid.map_diag(sns.distplot,rug=Truir_grid.map_lowe)
plt.show()

# %%
ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',hue='sex',data=tips,split=True)
# Out:
# <div id='9f9c7b2e-66f5-4d28-8d67-132eb048eae6'></div>

# %%
scatter=sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',fit_reg=False)
# Out:
# <div id='542c9f04-eeb4-4b7e-a812-6d719128e3d5'></div>

# %%
fig=sns.pairplot(tips,hue='sex')

# %%
scatter=sns.lmplot(x='total_bill',y='tip',data=tips,fit_reg=False,hue='sex',scatter_kws={'s':tips['size']*10})

# %%
scatter=sns.lmplot(x='total_bill',y='tip',data=tips,fit_reg=False,hue='sex'
                   markers=['o','x'],scatter_kws={'s':tips['size']*10})

# %%
anscombe_plot=sns.lmplot(x='x',y='y',data=anscombe,fit_reg=False)
# Out:
# <div id='db0cc657-35cd-4fd9-9df0-9186e2d97d86'></div>

# %%
anscombe_plot=sns.lmplot(x='x',y='y',data=anscombe,fit_reg=False,col='dataset',col_wrap=2

# %%
facet=sns.FaceGrid(tips,col='time')
facet.map(sns.distplot,'total_bill',rug=True)

# %%
facet=sns.FaceGrid(tips,col='day',hue='sex')
facet=facet.map(plt.scatter,'total_bill','tip)
facet=facet.add_legend()

# %%
facet=sns.FaceGrid(tips,col='time',row='smokwer',hue='sex)
facet.map(plt.scatter,'total_bill','tip')

# %% [markdown]
# # 데이터프레임과 시리즈로 그래프 그리기

# %%
ax=plt.subplots()
ax=tips['total_bill'].plot.hist()
# Out:
# <div id='e928fe63-7868-43a0-9868-9e6933a25a51'></div>

# %%
fig,ax=plt.subplots()
ax=tips[['total_bill','tip']].plot.hist(alpha=0.5,bins=20,ax=ax)
# Out:
# <div id='86399ac9-5b63-4ec0-aa26-5329e1ae727b'></div>

# %%
ax=plt.subplots()
ax=tips['tip'].plot.kde()
# Out:
# <div id='a654e9a1-6d4a-46bf-b45f-cf2a85bb160d'></div>

# %%
fig,ax=plt.subplots()
ax=tips.plot.scatter(x='total_bill',y='tip',ax=ax)
# Out:
# <div id='d6ce9806-72fa-4107-9a77-0e79896e816f'></div>

# %%
fig,ax=plt.subplots()
ax=tips.plot.hexbin(x='total_bill',y='tip',ax=ax)
# Out:
# <div id='5f26e58d-4242-4379-8b4c-234901dc7a68'></div>

# %%
fig,ax=plt.subplots()
ax=tips.plot.hexbin(x='total_bill',y='tip',gridsize=10,ax=ax)
# Out:
# <div id='714608e1-4a48-40bd-9188-7b7d10908122'></div>

# %%
fig,ax=plt.subplots()
ax=tips.plot.box(ax=ax)
# Out:
# <div id='496b3b69-9718-40e8-a853-cd2369c3c2f6'></div>

# %% [markdown]
# # 알아두면 좋아요

# %%
fig,ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',hue='sex',data=tips,split=True)
# Out:
# <div id='afae2854-75b7-42ce-8678-72a474467a09'></div>

# %%
sns.set_style('whitegrid')
fig,ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',hue='sex',data=tips,split=True)
# Out:
# <div id='184f7a27-ce86-41d5-b27d-9b54e074b5f2'></div>

# %%
fig=plt.figure()
seaborn_style=['darkgrid','whitegrid','dark','white','ticks']

for idx, style in enumerate(seaborn_styles):
    plot_position=idx+1
    with sns.axes_style(style):
        ax=fig.add_subplot(2,3,plot_position)
        violin=sns.violinplot(x='time',y='total_bill',data=tips,ax=ax)
        violin.set_title(style)
fig.tight_layout()
