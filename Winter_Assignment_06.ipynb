# %% [markdown]
# <a href="https://colab.research.google.com/github/Xerenia/13th_Seminar/blob/week01/Week_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def my_sq(x):
    return x ** 2

# %%
def avg_2(x, y):
    return (x + y) / 2

# %%
def avg_2(x, y):
    """두 숫자의 평균을 구하는 함수
    """
    return (x + y) / 2

# %%
my_calc_1 = my_sq(4)
print(my_calc_1)
# Out:
# 16

# %%
my_calc_2 = avg_2(10, 20)
print(my_calc_2)
# Out:
# 15.0

# %%
import pandas as pd

df = pd.DataFrame({"a": [10, 20, 30],
                   "b": [20, 30, 40]})
print(df)
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
print(df['a'] ** 2)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
print(type(df['a']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(df.iloc[0]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
sq = df['a'].apply(my_sq)
print(sq)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
def my_exp(x, e):
    return x ** e

# %%
cubed = my_exp(2, 3)

print(cubed)
# Out:
# 8

# %%
# my_exp(2)  # 오류

# %%
ex = df['a'].apply(my_exp, e=2)
print(ex)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
ex = df['a'].apply(my_exp, e=3)
print(ex)
# Out:
# 0     1000
# 1     8000
# 2    27000
# Name: a, dtype: int64

# %%
df = pd.DataFrame({"a": [10, 20, 30],
                   "b": [20, 30, 40]})
print(df)
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
def print_me(x):
    print(x)

# %%
df.apply(print_me, axis=0)
# Out:
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64
# 0    20
# 1    30
# 2    40
# Name: b, dtype: int64
# a    None
# b    None
# dtype: object

# %%
print(df['a'])
# Out:
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64

# %%
print(df['b'])
# Out:
# 0    20
# 1    30
# 2    40
# Name: b, dtype: int64

# %%
def avg_3(x, y, z):
    return (x + y + z) / 3

# %%
# print(df.apply(avg_3))  # 오류

# %%
def avg_3_apply(col):
    x = col[0]
    y = col[1]
    z = col[2]
    return (x + y + z) / 3

# %%
print(df.apply(avg_3_apply))
# Out:
# a    20.0
# b    30.0
# dtype: float64

# %%
# print(df.apply(avg_3_apply, axis=1))  # 오류

# %%
def avg_2_apply(row):
    x = row[0]
    y = row[1]
    return (x + y) / 2

# %%
print(df.apply(avg_2_apply, axis=1))
# Out:
# 0    15.0
# 1    25.0
# 2    35.0
# dtype: float64

# %%
df = pd.DataFrame({'a': [10, 20, 30],
                   'b': [20, 30, 40]})
print(df)
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
def my_sq(x):
    return x ** 2

df['a_sq'] = df['a'].apply(my_sq)
print(df)
# Out:
#     a   b  a_sq
# 0  10  20   100
# 1  20  30   400
# 2  30  40   900

# %%
df['a_sq_lamb'] = df['a'].apply(lambda x: x ** 2)
print(df)
# Out:
#     a   b  a_sq  a_sq_lamb
# 0  10  20   100        100
# 1  20  30   400        400
# 2  30  40   900        900

# %%
df = pd.DataFrame({"a": [10, 20, 30],
                   "b": [20, 30, 40]})
print(df)
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
def avg_2(x, y):
    return (x + y) / 2

# %%
print(avg_2(df['a'], df['b']))
# Out:
# 0    15.0
# 1    25.0
# 2    35.0
# dtype: float64

# %%
import numpy as np

def avg_2_mod(x, y):
    if (x == 20):
        return(np.NaN)
    else:
        return (x + y) / 2

# %%
# print(avg_2_mod(df['a'], df['b']))  # 오류

# %%
print(avg_2_mod(10, 20))
# Out:
# 15.0

# %%
print(avg_2_mod(20, 30))
# Out:
# nan

# %%
import numpy as np

avg_2_mod_vec = np.vectorize(avg_2_mod)

# %%
print(avg_2_mod_vec(df['a'], df['b']))
# Out:
# [15. nan 35.]

# %%
@np.vectorize
def v_avg_2_mod(x, y):
    if (x == 20):
        return(np.NaN)
    else:
        return (x + y) / 2

print(v_avg_2_mod(df['a'], df['b']))
# Out:
# [15. nan 35.]

# %%
import numba

@numba.vectorize
def v_avg_2_numba(x, y):
    if (int(x) == 20):
        return(np.NaN)
    else:
        return (x + y) / 2

# %%
# print(v_avg_2_numba(df['a'], df['b']))  # 오류

# %%
print(v_avg_2_numba(df['a'].values, df['b'].values))
# Out:
# [15. nan 35.]
