# %% [markdown]
# ###2/15(일)
# <시리즈와 데이터프레임 직접 만들기>
# 1. 시리즈 만들기

# %%
import pandas as pd
s = pd.Series(['banana', 42]) #시리즈 만들기
print(s)
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
s = pd.Series(['Wes McKinney', 'Creator of Pandas'])
print(s)
# Out:
# 0         Wes McKinney
# 1    Creator of Pandas
# dtype: object

# %%
#문자열을 인덱스로 지정
s = pd.Series(['Wes McKinney', 'Creator of Pandas'], index=['Person', 'Who'])
print(s)
# Out:
# Person         Wes McKinney
# Who       Creator of Pandas
# dtype: object

# %% [markdown]
# 3. 데이터프레임 만들기

# %%
scientists = pd.DataFrame({
    'Name': ['Rosaline Franklin', 'William Gosset'],
    'Occupation': ['Chemist', 'Statistician'],
    'Born': ['1920-07-25', '1876-06-13'],
    'Died': ['1958-04-16', '1937-10-16'],
    'Age': [37, 61]})
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
scientists = pd.DataFrame(
    data={'Occupation': ['Chemist', 'Statistician'],
          'Born': ['1920-07-25', '1876-06-13'],
          'Died': ['1958-04-16', '1937-10-16'],
          'Age': [37, 61]},
    index=['Rosaline Franklin', 'William Gosset'], #인덱스 지정
    columns=['Occupation', 'Born', 'Age', 'Died']) #열순서 지정
print(scientists)
# Out:
#                      Occupation        Born  Age        Died
# Rosaline Franklin       Chemist  1920-07-25   37  1958-04-16
# William Gosset     Statistician  1876-06-13   61  1937-10-16

# %%
from collections import OrderedDict #딕셔너리의 데이터 순서 유지

scientists = pd.DataFrame(OrderedDict([
    ('Name', ['Rosaline Franklin', 'William Gosset']),
    ('Occupation', ['Chemist', 'Statistician']),
    ('Born', ['1920-07-25', '1876-06-13']),
    ('Died', ['1958-04-16', '1937-10-16']),
    ('Age', [37, 61])
])
)
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %% [markdown]
# <데이터프레임에서 시리즈 선택하기>

# %%
scientists = pd.DataFrame(
    data={'Occupation': ['Chemist', 'Statistician'],
          'Born': ['1920-07-25', '1876-06-13'],
          'Died': ['1958-04-16', '1937-10-16'],
          'Age': [37, 61]},
    index=['Rosaline Franklin', 'William Gosset'],
    columns=['Occupation', 'Born', 'Died', 'Age'])

# %%
#시리즈를 선택하기 위해 loc 속성에 인덱스 전달
#loc : 인덱스 이름 사용해서 행과 열 추출하기
first_row = scientists.loc['William Gosset']
print(first_row)
print(type(first_row))
# Out:
# Occupation    Statistician
# Born            1876-06-13
# Died            1937-10-16
# Age                     61
# Name: William Gosset, dtype: object
# <class 'pandas.core.series.Series'>

# %%
print(first_row)
#object: 문자열 (age 61이 숫자여도)
# Out:
# Occupation    Statistician
# Born            1876-06-13
# Died            1937-10-16
# Age                     61
# Name: William Gosset, dtype: object

# %% [markdown]
# <index, values 속성과 keys 메서드 사용하기>

# %% [markdown]
# 1. index 속성 사용하기

# %%
print(first_row.index)
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='object')

# %% [markdown]
# 2. values 속성 사용하기

# %%
print(first_row.values)
# Out:
# ['Statistician' '1876-06-13' '1937-10-16' 61]

# %% [markdown]
# 3. keys 메서드 사용하기

# %%
print(first_row.keys())
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='object')

# %% [markdown]
# 4. index 속성 응용하기

# %%
print(first_row.index[0])
# Out:
# Occupation

# %% [markdown]
# 5. keys 메서드와 index 속성 응용하기

# %%
print(first_row.keys()[0])
#keys : 딕셔너리 내부 키들만 추출해서 리스트형식으로 반환하는 함수
# Out:
# Occupation

# %% [markdown]
# <시리즈의 mean, min, max, std 메서드 사용하기>

# %%
ages = scientists['Age']
print(ages)
# Out:
# Rosaline Franklin    37
# William Gosset       61
# Name: Age, dtype: int64

# %%
print(ages.mean())
# Out:
# 49.0

# %%
print(ages.min())
# Out:
# 37

# %%
print(ages.max())
# Out:
# 61

# %%
print(ages.std()) #표준편차
# Out:
# 16.97056274847714

# %% [markdown]
# <시리즈와 불린 추출 사용하기>

# %%
scientists = pd.read_csv('/content/scientists.csv')

# %%
ages = scientists['Age']
print(ages.max())
# Out:
# 90

# %%
print(ages.mean())
# Out:
# 59.125

# %%
print(ages[ages > ages.mean()])
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
print(ages > ages.mean())
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
print(type(ages > ages.mean()))
# Out:
# <class 'pandas.core.series.Series'>

# %%
manual_bool_values = [True, True, False, False, True, True, False, True]
print(ages[manual_bool_values])
#참인 인덱스의 데이터만 추출
# Out:
# 0    37
# 1    61
# 4    56
# 5    45
# 7    77
# Name: Age, dtype: int64

# %% [markdown]
# <벡터와 스칼라로 브로드캐스팅 수행하기>
# 브로드캐스팅 : 모든 데이터에 대해 한 번에 연산하는 것

# %%
print(ages + ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(ages * ages)
# Out:
# 0    1369
# 1    3721
# 2    8100
# 3    4356
# 4    3136
# 5    2025
# 6    1681
# 7    5929
# Name: Age, dtype: int64

# %%
print(ages + 100)
# Out:
# 0    137
# 1    161
# 2    190
# 3    166
# 4    156
# 5    145
# 6    141
# 7    177
# Name: Age, dtype: int64

# %%
print(ages * 2)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(pd.Series([1, 100]))
# Out:
# 0      1
# 1    100
# dtype: int64

# %%
print(ages + pd.Series([1, 100]))
#ages : 데이터 8개
# Out:
# 0     38.0
# 1    161.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# dtype: float64

# %%
rev_ages = ages.sort_index(ascending=False) #인덱스 역순
print(rev_ages)
# Out:
# 7    77
# 6    41
# 5    45
# 4    56
# 3    66
# 2    90
# 1    61
# 0    37
# Name: Age, dtype: int64

# %%
print(ages * 2)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(ages + rev_ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %% [markdown]
# <불린 추출과 브로드캐스팅>

# %%
print(scientists[scientists['Age'] > scientists['Age'].mean()])
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
print(scientists.loc[[True, True, False, True]])
#bool 벡터의 길이가 데이터프레임의 행 길이보다 짧으면 bool 벡터의 길이만큼만 연산
# Out:
#                 Name        Born        Died  Age    Occupation
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist
# 1     William Gosset  1876-06-13  1937-10-16   61  Statistician
# 3        Marie Curie  1867-11-07  1934-07-04   66       Chemist

# %%
print(scientists * 2)
# Out:
#                                        Name                  Born  \
# 0        Rosaline FranklinRosaline Franklin  1920-07-251920-07-25
# 1              William GossetWilliam Gosset  1876-06-131876-06-13
# 2  Florence NightingaleFlorence Nightingale  1820-05-121820-05-12
# 3                    Marie CurieMarie Curie  1867-11-071867-11-07
# 4                Rachel CarsonRachel Carson  1907-05-271907-05-27
# 5                        John SnowJohn Snow  1813-03-151813-03-15
# 6                    Alan TuringAlan Turing  1912-06-231912-06-23
# 7                  Johann GaussJohann Gauss  1777-04-301777-04-30
#
#                    Died  Age                            Occupation
# 0  1958-04-161958-04-16   74                        ChemistChemist
# 1  1937-10-161937-10-16  122              StatisticianStatistician
# 2  1910-08-131910-08-13  180                            NurseNurse
# 3  1934-07-041934-07-04  132                        ChemistChemist
# ...

# %% [markdown]
# <시리즈와 데이터프레임의 데이터 처리하기>

# %%
print(scientists['Born'].dtype)
print(scientists['Died'].dtype)
#object : 문자열
# Out:
# object
# object

# %%
born_datetime = pd.to_datetime(scientists['Born'], format='%Y-%m-%d')
print(born_datetime)
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
died_datetime = pd.to_datetime(scientists['Died'], format='%Y-%m-%d')
print(died_datetime)
# Out:
# 0   1958-04-16
# 1   1937-10-16
# 2   1910-08-13
# 3   1934-07-04
# 4   1964-04-14
# 5   1858-06-16
# 6   1954-06-07
# 7   1855-02-23
# Name: Died, dtype: datetime64[ns]

# %%
scientists['born_dt'], scientists['died_dt'] = (born_datetime, died_datetime)
#새로운 열로 추가
print(scientists.head())
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt
# 0 1958-04-16
# 1 1937-10-16
# 2 1910-08-13
# 3 1934-07-04
# 4 1964-04-14

# %%
print(scientists.shape)
#(행크기, 열크기)
# Out:
# (8, 7)

# %%
scientists['age_days_dt'] = (scientists['died_dt'] -  scientists['born_dt'])
print(scientists)
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt age_days_dt
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12 1910-08-13  32964 days
# 3 1867-11-07 1934-07-04  24345 days
# 4 1907-05-27 1964-04-14  20777 days
# 5 1813-03-15 1858-06-16  16529 days
# 6 1912-06-23 1954-06-07  15324 days
# ...

# %% [markdown]
# 5. 시리즈, 데이터프레임의 데이터 섞기

# %%
print(scientists['Age'])
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %% [markdown]
# ### 2/16(월)

# %%
import random
random.seed(42)
random.shuffle(scientists['Age']) #랜덤 라이브러리에 셔플 메서드 사용
print(scientists['Age'])
# Out:
# C:\Users\fermat39\Anaconda3\lib\random.py:275: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   x[i], x[j] = x[j], x[i]
# 0    66
# 1    56
# 2    41
# 3    77
# 4    90
# 5    45
# 6    37
# 7    61
# Name: Age, dtype: int64

# %% [markdown]
# 7. 데이터프레임의 열 삭제하기

# %%
print(scientists.columns)
# Out:
# Index(['Name', 'Born', 'Died', 'Age', 'Occupation', 'born_dt', 'died_dt',
#        'age_days_dt'],
#       dtype='object')

# %%
scientists_dropped = scientists.drop(['Age'], axis=1)
#drop : 열 삭제 / 삭제한 열 반환
print(scientists_dropped.columns)
# Out:
# Index(['Name', 'Born', 'Died', 'Occupation', 'born_dt', 'died_dt',
#        'age_days_dt'],
#       dtype='object')

# %% [markdown]
# <데이터를 피클, CSV, TSV 파일로 저장하고 불러오기>

# %% [markdown]
# <데이터 저장하고 불러오기>
# 1. 피클로 저장하기
# 피클 : 데이터를 바이너리 형태로 직렬화한 오브젝트 저장하기

# %%
names = scientists['Name']

# %%
#시리즈를 피클로 저장
names.to_pickle('/content/scientists_names_series.pickle')

# %%
#데이터프레임을 피클로 저장
scientists.to_pickle('/content/scientists_names_series.pickle')

# %%
scientist_names_from_pickle = pd.read_pickle('/content/scientists_names_series.pickle')
#read_pickle로 읽어야 함
print(scientist_names_from_pickle)
# Out:
# 0    Rosaline Franklin
# 1       William Gosset
# Name: Name, dtype: object

# %%
scientists_from_pickle = pd.read_pickle('/content/scientists_df.pickle')
print(scientists_from_pickle)
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   66             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   56        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   41               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   37  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   61       Mathematician
#
#      born_dt    died_dt age_days_dt
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12 1910-08-13  32964 days
# 3 1867-11-07 1934-07-04  24345 days
# 4 1907-05-27 1964-04-14  20777 days
# 5 1813-03-15 1858-06-16  16529 days
# 6 1912-06-23 1954-06-07  15324 days
# ...

# %% [markdown]
# 4. CSV 파일과 TSV 파일로 저장하기
# csv : 쉼표로 데이터 구분
# tsv : 탭으로 데이터 구분

# %%
names.to_csv('/content/scientist_names_series.csv') #시리즈

# %%
scientists.to_csv('/content/scientists_df.tsv', sep='\t') #데이터프레임

# %%
scientists.to_csv('/content/scientists_df_no_index.csv', index=False)

# %%
#시리즈와 데이터프레임을 엑셀 파일로 저장하기
names_df = names.to_frame()

import xlwt
names_df.to_excel('../output/scientists_names_series_df.xls')

import openpyxl
names_df.to_excel('../output/scientists_names_series_df.xlsx')
